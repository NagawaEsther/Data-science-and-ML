# %% [markdown]
# # Session 4 Ds-ML Lecture Arrays,Lists,Tuples

# %%
# import numpy as library
import numpy as np

# %%
# creating array in python - where a list is the object and np-means the subject

a= np.array ([0,1,2,3])

# note:np means numpy libray,dot (.)- means the array

# %%
# check the type of an array 
type(a)
# Out:
# numpy.ndarray

# %%
[1,2,3,4]
# Out:
# [1, 2, 3, 4]

# %%
# we can also creat an empty list
[]
# Out:
# []

# %%
Tuple = 1,2,3,4 # How to create a tuple

# %%
print (Tuple)  # calling a tuple or getting an output
# Out:
# (1, 2, 3, 4)

# %%
Tuple1= "data science" # a tuple once created can not be changed
print (Tuple1)
# Out:
# data science

# %%
a=(6,7,8,9,10)
b=(1,2,3,4,5)
print(a+b)
# Out:
# (6, 7, 8, 9, 10, 1, 2, 3, 4, 5)
